# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Даны-значения-величины-заработной-платы-заемщиков-банка-(zp)-и-значения-их-поведенческого-кредитного-скоринга-(ks):-zp-=-[35,-45,-190,-200,-40,-70,-54,-150,-120,-110],-ks-=-[401,-574,-874,-919,-459,-739,-653,-902,-746,-832].-Найдите-ковариацию-этих-двух-величин-с-помощью-элементарных-действий,-а-затем-с-помощью-функции-cov-из-numpy-Полученные-значения-должны-быть-равны.-Найдите-коэффициент-корреляции-Пирсона-с-помощью-ковариации-и-среднеквадратичных-отклонений-двух-признаков,-а-затем-с-использованием-функций-из-библиотек-numpy-и-pandas." data-toc-modified-id="Даны-значения-величины-заработной-платы-заемщиков-банка-(zp)-и-значения-их-поведенческого-кредитного-скоринга-(ks):-zp-=-[35,-45,-190,-200,-40,-70,-54,-150,-120,-110],-ks-=-[401,-574,-874,-919,-459,-739,-653,-902,-746,-832].-Найдите-ковариацию-этих-двух-величин-с-помощью-элементарных-действий,-а-затем-с-помощью-функции-cov-из-numpy-Полученные-значения-должны-быть-равны.-Найдите-коэффициент-корреляции-Пирсона-с-помощью-ковариации-и-среднеквадратичных-отклонений-двух-признаков,-а-затем-с-использованием-функций-из-библиотек-numpy-и-pandas.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks): zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110], ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]. Найдите ковариацию этих двух величин с помощью элементарных действий, а затем с помощью функции cov из numpy Полученные значения должны быть равны. Найдите коэффициент корреляции Пирсона с помощью ковариации и среднеквадратичных отклонений двух признаков, а затем с использованием функций из библиотек numpy и pandas.</a></span></li><li><span><a href="#Измерены-значения-IQ-выборки-студентов,-обучающихся-в-местных-технических-вузах:-131,-125,-115,-122,-131,-115,-107,-99,-125,-111.-Известно,-что-в-генеральной-совокупности-IQ-распределен-нормально.-Найдите-доверительный-интервал-для-математического-ожидания-с-надежностью-0.95." data-toc-modified-id="Измерены-значения-IQ-выборки-студентов,-обучающихся-в-местных-технических-вузах:-131,-125,-115,-122,-131,-115,-107,-99,-125,-111.-Известно,-что-в-генеральной-совокупности-IQ-распределен-нормально.-Найдите-доверительный-интервал-для-математического-ожидания-с-надежностью-0.95.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Измерены значения IQ выборки студентов, обучающихся в местных технических вузах: 131, 125, 115, 122, 131, 115, 107, 99, 125, 111. Известно, что в генеральной совокупности IQ распределен нормально. Найдите доверительный интервал для математического ожидания с надежностью 0.95.</a></span></li><li><span><a href="#Известно,-что-рост-футболистов-в-сборной-распределен-нормально-с-дисперсией-генеральной-совокупности,-равной-25-кв.см.-Объем-выборки-равен-27,-среднее-выборочное-составляет-174.2.-Найдите-доверительный-интервал-для-математического-ожидания-с-надежностью-0.95." data-toc-modified-id="Известно,-что-рост-футболистов-в-сборной-распределен-нормально-с-дисперсией-генеральной-совокупности,-равной-25-кв.см.-Объем-выборки-равен-27,-среднее-выборочное-составляет-174.2.-Найдите-доверительный-интервал-для-математического-ожидания-с-надежностью-0.95.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Известно, что рост футболистов в сборной распределен нормально с дисперсией генеральной совокупности, равной 25 кв.см. Объем выборки равен 27, среднее выборочное составляет 174.2. Найдите доверительный интервал для математического ожидания с надежностью 0.95.</a></span></li></ul></div>

# %% [markdown]
# ### Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks): zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110], ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]. Найдите ковариацию этих двух величин с помощью элементарных действий, а затем с помощью функции cov из numpy Полученные значения должны быть равны. Найдите коэффициент корреляции Пирсона с помощью ковариации и среднеквадратичных отклонений двух признаков, а затем с использованием функций из библиотек numpy и pandas.

# %%
import numpy as np

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
m1 = np.mean(zp)
m1
# Out:
# 101.4

# %%
m2 = np.mean(ks)
m2
# Out:
# 709.9

# %%
M = np.mean(zp * ks)
M
# Out:
# 81141.7

# %%
cov = M - m1 * m2
cov
# Out:
# 9157.839999999997

# %%
np.cov(zp, ks, ddof=0) # Проверили смещенную ковариацию
# Out:
# array([[ 3494.64,  9157.84],
#        [ 9157.84, 30468.89]])

# %%
# Коэффициент Пирсона
std1 = np.std(zp)
std2 = np.std(ks)
r = cov / (std1 * std2)
r
# Out:
# 0.8874900920739158

# %%
np.corrcoef(zp, ks) # Проверка
# Out:
# array([[1.        , 0.88749009],
#        [0.88749009, 1.        ]])

# %% [markdown]
# ### Измерены значения IQ выборки студентов, обучающихся в местных технических вузах: 131, 125, 115, 122, 131, 115, 107, 99, 125, 111. Известно, что в генеральной совокупности IQ распределен нормально. Найдите доверительный интервал для математического ожидания с надежностью 0.95.

# %%
iq = [131, 125, 115, 122, 131, 115, 107, 99, 125, 111]

# %%
M = np.mean(iq)
std1 = np.std(iq, ddof=1)
n = len(iq)
M, std1, n
# Out:
# (118.1, 10.54566788359614, 10)

# %%
# Т критерий для 10 измерений (9 степеней свободы), 95% надежность
t_95_9 = 1.833

# %%
x1 = M - t_95_9 * std1 / (n ** 0.5)
x2 = M + t_95_9 * std1 / (n ** 0.5)
print('Доверительный интервал:', (round(x1,2), round(x2,2)))
# Out:
# Доверительный интервал: (111.99, 124.21)

# %% [markdown]
# ### Известно, что рост футболистов в сборной распределен нормально с дисперсией генеральной совокупности, равной 25 кв.см. Объем выборки равен 27, среднее выборочное составляет 174.2. Найдите доверительный интервал для математического ожидания с надежностью 0.95.

# %%
D = 25
std1 = D ** 0.5
n = 27
M = 174.2

# %%
# В сборной может быть максимально от 23 до 28 футболистов, в зависимости от чемпионата.
# Значит есть 2 варианта, 27 или 28 количество в генеральной совокупности
print('При 27 игроках в сборной доверительный интервал будет равен М:', M, 'или', (M, M))
# Для второго варианта:
# z критерий для 95% надежности:
z = 1.645
x1 = M - z * std1 / (n ** 0.5)
x2 = M + z * std1 / (n ** 0.5)
print('При 28 игроках в сборной доверительный интервал будет равен:', (x1, x2))
# Out:
# При 27 игроках в сборной доверительный интервал будет равен М: 174.2 или (174.2, 174.2)
# При 28 игроках в сборной доверительный интервал будет равен: (172.61709801197176, 175.78290198802821)
